# %%
import pandas as pd

mevzuat_link = pd.read_csv("data/mevzuat_links.csv",sep=",")
mevzuat = pd.read_csv("data/mevzuat_content.csv",sep=",")

# %%
mevzuat['Mevzuat Başlığı'] = mevzuat['İçerik'].str.split('BİRİNCİ BÖLÜM').str[0].str.strip()
mevzuat = mevzuat[['Üniversite', 'Link', 'İçerik', 'Mevzuat Başlığı', 'Resmi Gazete Tarihi', 'Resmi Gazete Sayısı', 'Mevzuat No']]

# %%
mevzuat
# Out:
#                                 Üniversite  \
# 0                Abdullah Gül Üniversitesi
# 1                Abdullah Gül Üniversitesi
# 2                Abdullah Gül Üniversitesi
# 3                Abdullah Gül Üniversitesi
# 4                Abdullah Gül Üniversitesi
# ...                                    ...
# 4783  Zonguldak Bülent Ecevit Üniversitesi
# 4784  Zonguldak Bülent Ecevit Üniversitesi
# 4785  Zonguldak Bülent Ecevit Üniversitesi
# 4786  Zonguldak Bülent Ecevit Üniversitesi
# 4787  Zonguldak Bülent Ecevit Üniversitesi
#
#                                                    Link  \
# 0     https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=3...
# 1     https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=3...
# 2     https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=3...
# 3     https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=3...
# 4     https://www.mevzuat.gov.tr/mevzuat?MevzuatNo=2...
# ...                                                 ...
# ...
